# %%
import numpy as np
import pandas as pd

from sklearn import linear_model
ld = pd.read_csv('laptop_data.csv')
ld.sample(5)
# Out:
#       Unnamed: 0 Company            TypeName  Inches
# 554          554      HP            Notebook    17.3  \
# 653          653     MSI              Gaming    15.6
# 982          982  Lenovo            Notebook    15.6
# 1149        1149  Lenovo  2 in 1 Convertible    14.0
# 1175        1175    Asus            Notebook    14.0
#
#                      ScreenResolution                          Cpu  Ram
# 554                 Full HD 1920x1080   Intel Core i7 7500U 2.7GHz  8GB  \
# 653                 Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  8GB
# 982                 Full HD 1920x1080  AMD A12-Series 9720P 3.6GHz  6GB
# 1149  IPS Panel Touchscreen 2560x1440   Intel Core i7 6500U 2.5GHz  8GB
# 1175                Full HD 1920x1080   Intel Core i3 7100U 2.4GHz  4GB
#
#                     Memory                         Gpu       OpSys  Weight
# 554                1TB HDD        Nvidia GeForce 930MX  Windows 10  2.63kg  \
# 653   128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10   2.2kg
# 982              256GB SSD              AMD Radeon 530  Windows 10   2.2kg
# 1149             256GB SSD       Intel HD Graphics 520  Windows 10  1.27kg
# 1175             256GB SSD       Intel HD Graphics 620  Windows 10     2kg
#
#            Price
# 554    68198.400
# 653    63499.104
# 982    29250.720
# 1149  124621.920
# 1175   40972.320

# %%
ld.drop(columns=["Weight","OpSys","Unnamed: 0","Company","TypeName","Cpu","ScreenResolution","Inches","Gpu"],inplace=True)
ld.sample(5)
# Out:
#      Ram                Memory       Price
# 47   8GB  256GB SSD +  1TB HDD  69210.7200
# 876  4GB               1TB HDD  21258.1872
# 290  2GB              16GB SSD  10602.7200
# 982  6GB             256GB SSD  29250.7200
# 651  8GB               1TB HDD  37775.5200

# %%
# dividing memory into 3 columns of HDD & SSD & Flash storage
memory = ld.Memory

def getHybrid(x,query):
     idx = x.find(query)
     if idx==-1:
        return 0
     ar = x[0:idx].split("+")
     ans =  ar[len(ar)-1]
     tb = ans.find("TB")
     if tb!=-1:
        val = float(ans[0:tb])
        val = val*1024
        ans = str(val)+"GB"
     gb = ans.find("GB")
     return float(ans[0:gb])


#print(memory)
hdd = np.array([getHybrid(xi,"HDD") for xi in memory])
ssd = np.array([getHybrid(xi,"SSD") for xi in memory])
flash = np.array([getHybrid(xi,"Flash") for xi in memory])
Hybrid = np.array([getHybrid(xi,"Hybrid") for xi in memory])
ld["hdd"]=hdd
ld["ssd"]=ssd
ld["flash"]=flash
ld["hybrid"]=Hybrid
ld.drop(columns=["Memory"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6784\1344018837.py in ?()
#       1 # dividing memory into 3 columns of HDD & SSD & Flash storage
# ----> 2 memory = ld.Memory
#       3
#       4 def getHybrid(x,query):
#       5      idx = x.find(query)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Memory'

# %%
ld['Ram'] = ld['Ram'].str.replace('GB','')
ld["Ram"]= ld["Ram"].astype('float')
ld["Price"] = ld["Price"].astype("float")
ld.sample(10)
# Out:
#        Ram        Price     hdd    ssd  flash  hybrid
# 551    8.0   59513.2272     0.0  256.0    0.0     0.0
# 673    4.0   18594.7200     0.0  128.0    0.0     0.0
# 1120   4.0   10442.8800     0.0    0.0   32.0     0.0
# 346    2.0   14865.1200     0.0    0.0   32.0     0.0
# 1053   4.0   52161.1200     0.0  256.0    0.0     0.0
# 334    8.0   53226.7200     0.0  256.0    0.0     0.0
# 988    8.0   39906.7200  1024.0    0.0    0.0     0.0
# 25     4.0   22305.1392  1024.0    0.0    0.0     0.0
# 1050  16.0  139593.6000     0.0  256.0    0.0     0.0
# 941    4.0   28238.4000  1024.0    0.0    0.0     0.0

# %%
reg = linear_model.LinearRegression()
reg.fit(ld.drop(columns="Price"),ld['Price'])
ans = reg.predict([[16,1024,0,0,0]])
print(ans)
# Out:
# [75208.69577824]
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
